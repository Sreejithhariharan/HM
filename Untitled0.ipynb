# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreejithhariharan/HM/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=('a','b','c','d','e')
y=(1,2,3,4,5)

# %%
plt.bar(x,y,width=0.5,color='c')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,y, color='c')
# Out:
# <BarContainer object of 5 artists>

# %%
import seaborn as sns

# %%
x=('c','b','a','e','d')
y=('1','2','3','4','5')

# %%
iris=sns.load_dataset("iris")

# %%
sns.lineplot(data=iris,x="sepal_length",y="sepal_width",hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>
